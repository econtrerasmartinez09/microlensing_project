# %% [markdown]
# Fitting a DE algorith to a PSPL model for a Gaia21bsg binary event with no parallax (i.e. parallax = None) to begin with

# %%
import pyLIMA

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import csv

from pyLIMA.fits import DE_fit
from pyLIMA.fits import TRF_fit
from pyLIMA.models import PSPL_model
from pyLIMA.models import USBL_model, pyLIMA_fancy_parameters
from pyLIMA.outputs import pyLIMA_plots

from pyLIMA import event
from pyLIMA import telescopes

# %%
your_event = event.Event(ra=262.75616,dec=-21.40123)   # setting no parallax for starters
your_event.name = 'Gaia21bsg_binary'

# %%
data_1 = np.loadtxt('data/star_20957_Gaia21bsg_fs01_ip_reduced.dat')
telescope_1 = telescopes.Telescope(name='Gaia_20957_i',
                                  camera_filter = 'I',
                                  light_curve = data_1.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

data_2 = np.loadtxt('data/star_50085_Gaia21bsg_gp_reduced.dat')
telescope_2 = telescopes.Telescope(name='Gaia__50085_g',
                                  camera_filter = 'G',
                                  light_curve = data_2.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

data_3 = np.loadtxt('data/star_79874_Gaia21bsg_ip_reduced.dat')
telescope_3 = telescopes.Telescope(name='Gaia_79874_i',
                                  camera_filter = 'I',
                                  light_curve = data_3.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

# %%
data_4 = np.loadtxt('data/reduced_atlas_c.dat',delimiter=' ')   
telescope_4 = telescopes.Telescope(name='ATLAS_c',
                                  camera_filter = 'C',
                                  light_curve = data_4.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

# %%
data_5 = np.loadtxt('data/reduced_atlas_o.dat',delimiter=' ')   
telescope_5 = telescopes.Telescope(name='ATLAS_o',
                                  camera_filter = 'O',
                                  light_curve = data_5.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

# %%
data_6 = np.loadtxt('data/reduced_ztf.dat',delimiter=' ')   
telescope_6 = telescopes.Telescope(name='ZTF_r',
                                  camera_filter = 'R',
                                  light_curve = data_6.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD','mag','mag'])

# %%
data_7 = np.loadtxt('data/reduced_gaia.dat',delimiter=' ')   
telescope_7 = telescopes.Telescope(name='Gaia_g',
                                  camera_filter = 'G',
                                  light_curve = data_7.astype(float),
                                  light_curve_names = ['time','mag','err_mag'],
                                  light_curve_units = ['JD', 'mag','mag'])

# %%
your_event.telescopes.append(telescope_1)
your_event.telescopes.append(telescope_2)
your_event.telescopes.append(telescope_3)
your_event.telescopes.append(telescope_4)
your_event.telescopes.append(telescope_5)
your_event.telescopes.append(telescope_6)
your_event.telescopes.append(telescope_7)

# %%
your_event.find_survey('Gaia')

# %%
your_event.check_event()
# Out:
# check_event  : Everything looks fine...

# %%
pspl = PSPL_model.PSPLmodel(your_event)

# %%
fit_1 = DE_fit.DEfit(pspl)

# a priori parameters from gaia21bsg base model code (t0,u0,tE)

fit_1.model_parameter_guess = [2.45935387e+06, 9.99759380e-01, 1.12577028e+00]

# %%
fit_1.fit()
# Out:
# /home/ezequiel/pyLIMA-env/pyLIMA/pyLIMA/models/ML_model.py:483: RankWarning: Polyfit may be poorly conditioned
#   self.derive_telescope_flux(telescope, pyLIMA_parameters, magnification)
# /home/ezequiel/pyLIMA-env/pyLIMA/pyLIMA/models/ML_model.py:483: RankWarning: Polyfit may be poorly conditioned
#   self.derive_telescope_flux(telescope, pyLIMA_parameters, magnification)
# DE converge to objective function : f(x) =  70639.30790719108
# DE converge to parameters : =  ['2459353.8690843815' '0.9995495897287971' '1.1247304736905335']
# fit  : Differential Evolution fit SUCCESS
# best_model: [2.45935387e+06 9.99549590e-01 1.12473047e+00] -ln(likelihood) 70639.30790719108

# %%
pyLIMA_plots.plot_lightcurves(pspl,fit_1.fit_results['best_model'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="749.8333333333334">
# /home/ezequiel/pyLIMA-env/pyLIMA/pyLIMA/outputs/pyLIMA_plots.py:1017: RuntimeWarning: invalid value encountered in log10
#   np.log10(ref_source * magni + ref_blend)
# /home/ezequiel/pyLIMA-env/pyLIMA/pyLIMA/outputs/pyLIMA_plots.py:1112: RuntimeWarning: invalid value encountered in log10
#   np.log10(model_flux)

# %%
fancy = pyLIMA_fancy_parameters.standard_fancy_parameters
pspl2 = PSPL_model.PSPLmodel(your_event,fancy_parameters=fancy,parallax=['None',2.45935387e+06])
# Out:
# I skip the fancy parameter rho, as it is not part of model PSPL
# I skip the fancy parameter separation, as it is not part of model PSPL
# I skip the fancy parameter mass_ratio, as it is not part of model PSPL

# %%
usbl = USBL_model.USBLmodel(your_event,fancy_parameters=fancy,parallax=['None',2.45935387e+06])

# %%
fit_2 = DE_fit.DEfit(usbl, telescopes_fluxes_method='polyfit', DE_population_size=10, max_iteration=10000, display_progress=True)

# %%
fit_2.fit_parameters['t0'][1] = [2459282.00, 2459413.00] # t0 limits, changed
fit_2.fit_parameters['u0'][1] = [0.10, 0.15] # u0 limits, computed and changed
fit_2.fit_parameters['log_tE'][1] = [4.09, 4.24] # logtE limits in days, changed

fit_2.fit_parameters['log_rho'][1] = [-6.042577190325831, -2.088329855444677] 
fit_2.fit_parameters['log_separation'][1] = [-4.40904379, -0.13026733] # log_s limits, 
fit_2.fit_parameters['log_mass_ratio'][1] = [-7.472756449463439, 8.15962396e-03] # log_q limits, 
fit_2.fit_parameters['alpha'][1] = [-3.14, 3.14] # alpha limits (in radians), perfect as is

#fit_2.fit_parameters['piEN'][1] = [-0.5, 0.5]   # believe not necessary right now since parallax = 'None'
#fit_2.fit_parameters['piEE'][1] = [-0.5, 0.5]

# %%
import multiprocessing as mul
pool = mul.Pool(processes=4)

# %%
perform_long_fit = True

# %%
### Fit the model:
if perform_long_fit == True:
    fit_2.fit(computational_pool = pool)
    
    # Save it
    np.save('results_USBL_gaia21bsg.npy', fit_2.fit_results['DE_population'])

else:
    # Use the precomputed Differential Evolution (DE) results:
    fit_2.fit_results['DE_population'] = np.load('./data/results_USBL_DE_966.npy')
    fit_2.fit_results['best_model'] = fit_2.fit_results['DE_population'][346501][0:-1]
    #fit_2.fit_results['best_model'] = [2457205.21, 0.0109583755, 1.78218726, -2.89415218, 0.0475121003, -3.79996021, 2.2549
# Out:
# /home/ezequiel/pyLIMA-env/lib/python3.11/site-packages/scipy/optimize/_differentialevolution.py:387: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 150751
# differential_evolution step 2: f(x)= 150751
# differential_evolution step 3: f(x)= 150751
# differential_evolution step 4: f(x)= 150751
# differential_evolution step 5: f(x)= 150751
# differential_evolution step 6: f(x)= 150751
# differential_evolution step 7: f(x)= 150751
# differential_evolution step 8: f(x)= 150751
# differential_evolution step 9: f(x)= 150751
# differential_evolution step 10: f(x)= 150751
# differential_evolution step 11: f(x)= 150751
# differential_evolution step 12: f(x)= 150751
# differential_evolution step 13: f(x)= 150751
# differential_evolution step 14: f(x)= 150751
# differential_evolution step 15: f(x)= 150751
# differential_evolution step 16: f(x)= 150751
# differential_evolution step 17: f(x)= 149434
# differential_evolution step 18: f(x)= 149434
# differential_evolution step 19: f(x)= 149434
# differential_evolution step 20: f(x)= 149434
# differential_evolution step 21: f(x)= 149434
# differential_evolution step 22: f(x)= 149434
# differential_evolution step 23: f(x)= 149434
# differential_evolution step 24: f(x)= 149434
# differential_evolution step 25: f(x)= 149434
# differential_evolution step 26: f(x)= 149434
# differential_evolution step 27: f(x)= 149434
# differential_evolution step 28: f(x)= 149434
# differential_evolution step 29: f(x)= 149434
# differential_evolution step 30: f(x)= 149434
# differential_evolution step 31: f(x)= 149268
# differential_evolution step 32: f(x)= 149268
# differential_evolution step 33: f(x)= 149268
# differential_evolution step 34: f(x)= 149268
# differential_evolution step 35: f(x)= 149268
# differential_evolution step 36: f(x)= 149268
# differential_evolution step 37: f(x)= 149268
# differential_evolution step 38: f(x)= 149268
# differential_evolution step 39: f(x)= 149268
# differential_evolution step 40: f(x)= 149268
# differential_evolution step 41: f(x)= 149268
# differential_evolution step 42: f(x)= 149268
# differential_evolution step 43: f(x)= 149268
# differential_evolution step 44: f(x)= 149268
# differential_evolution step 45: f(x)= 149268
# differential_evolution step 46: f(x)= 149268
# differential_evolution step 47: f(x)= 149268
# differential_evolution step 48: f(x)= 149268
# differential_evolution step 49: f(x)= 149268
# differential_evolution step 50: f(x)= 149268
# differential_evolution step 51: f(x)= 149268
# differential_evolution step 52: f(x)= 149268
# differential_evolution step 53: f(x)= 149268
# differential_evolution step 54: f(x)= 149268
# differential_evolution step 55: f(x)= 149268
# differential_evolution step 56: f(x)= 149268
# differential_evolution step 57: f(x)= 149268
# differential_evolution step 58: f(x)= 149268
# differential_evolution step 59: f(x)= 149268
# differential_evolution step 60: f(x)= 149268
# differential_evolution step 61: f(x)= 148311
# differential_evolution step 62: f(x)= 148311
# differential_evolution step 63: f(x)= 148311
# differential_evolution step 64: f(x)= 148311
# differential_evolution step 65: f(x)= 145687
# differential_evolution step 66: f(x)= 145687
# differential_evolution step 67: f(x)= 145687
# differential_evolution step 68: f(x)= 145687
# differential_evolution step 69: f(x)= 145687
# differential_evolution step 70: f(x)= 145687
# differential_evolution step 71: f(x)= 140617
# differential_evolution step 72: f(x)= 140617
# differential_evolution step 73: f(x)= 138987
# differential_evolution step 74: f(x)= 138987
# differential_evolution step 75: f(x)= 138987
# differential_evolution step 76: f(x)= 138987
# differential_evolution step 77: f(x)= 138987
# differential_evolution step 78: f(x)= 138987
# differential_evolution step 79: f(x)= 138987
# differential_evolution step 80: f(x)= 138987
# differential_evolution step 81: f(x)= 138987
# differential_evolution step 82: f(x)= 138987
# differential_evolution step 83: f(x)= 138987
# differential_evolution step 84: f(x)= 138987
# differential_evolution step 85: f(x)= 138987
# differential_evolution step 86: f(x)= 138987
# differential_evolution step 87: f(x)= 138987
# differential_evolution step 88: f(x)= 138987
# differential_evolution step 89: f(x)= 138987
# differential_evolution step 90: f(x)= 138987
# differential_evolution step 91: f(x)= 138987
# differential_evolution step 92: f(x)= 138987
# differential_evolution step 93: f(x)= 138987
# differential_evolution step 94: f(x)= 138987
# differential_evolution step 95: f(x)= 138987
# differential_evolution step 96: f(x)= 138987
# differential_evolution step 97: f(x)= 138987
# differential_evolution step 98: f(x)= 138987
# differential_evolution step 99: f(x)= 138987
# differential_evolution step 100: f(x)= 138987
# differential_evolution step 101: f(x)= 138987
# differential_evolution step 102: f(x)= 138987
# differential_evolution step 103: f(x)= 138987
# differential_evolution step 104: f(x)= 138987
# differential_evolution step 105: f(x)= 138987
# differential_evolution step 106: f(x)= 138987
# differential_evolution step 107: f(x)= 138987
# differential_evolution step 108: f(x)= 138987
# differential_evolution step 109: f(x)= 138987
# differential_evolution step 110: f(x)= 137933
# differential_evolution step 111: f(x)= 135950
# differential_evolution step 112: f(x)= 135950
# differential_evolution step 113: f(x)= 135950
# differential_evolution step 114: f(x)= 135950
# differential_evolution step 115: f(x)= 135950
# differential_evolution step 116: f(x)= 135950
# differential_evolution step 117: f(x)= 135950
# differential_evolution step 118: f(x)= 135950
# differential_evolution step 119: f(x)= 135950
# differential_evolution step 120: f(x)= 135950
# differential_evolution step 121: f(x)= 135950
# differential_evolution step 122: f(x)= 135950
# differential_evolution step 123: f(x)= 135950
# differential_evolution step 124: f(x)= 135950
# differential_evolution step 125: f(x)= 135950
# differential_evolution step 126: f(x)= 135950
# differential_evolution step 127: f(x)= 135950
# differential_evolution step 128: f(x)= 100737
# differential_evolution step 129: f(x)= 100737
# differential_evolution step 130: f(x)= 100737
# differential_evolution step 131: f(x)= 100737
# differential_evolution step 132: f(x)= 100737
# differential_evolution step 133: f(x)= 100737
# differential_evolution step 134: f(x)= 100737
# differential_evolution step 135: f(x)= 93305.8
# differential_evolution step 136: f(x)= 93305.8
# differential_evolution step 137: f(x)= 93305.8
# differential_evolution step 138: f(x)= 93305.8
# differential_evolution step 139: f(x)= 93305.8
# differential_evolution step 140: f(x)= 93305.8
# differential_evolution step 141: f(x)= 93305.8
# differential_evolution step 142: f(x)= 93305.8
# differential_evolution step 143: f(x)= 93305.8
# differential_evolution step 144: f(x)= 93305.8
# differential_evolution step 145: f(x)= 93305.8
# differential_evolution step 146: f(x)= 93305.8
# differential_evolution step 147: f(x)= 93305.8
# differential_evolution step 148: f(x)= 93305.8
# differential_evolution step 149: f(x)= 93305.8
# differential_evolution step 150: f(x)= 93305.8
# differential_evolution step 151: f(x)= 93305.8
# differential_evolution step 152: f(x)= 93305.8
# differential_evolution step 153: f(x)= 93305.8
# differential_evolution step 154: f(x)= 93305.8
# differential_evolution step 155: f(x)= 93305.8
# differential_evolution step 156: f(x)= 93305.8
# differential_evolution step 157: f(x)= 93305.8
# differential_evolution step 158: f(x)= 93305.8
# differential_evolution step 159: f(x)= 93305.8
# differential_evolution step 160: f(x)= 93305.8
# differential_evolution step 161: f(x)= 93305.8
# differential_evolution step 162: f(x)= 93305.8
# differential_evolution step 163: f(x)= 93305.8
# differential_evolution step 164: f(x)= 93305.8
# differential_evolution step 165: f(x)= 93305.8
# differential_evolution step 166: f(x)= 93305.8
# differential_evolution step 167: f(x)= 93305.8
# differential_evolution step 168: f(x)= 93305.8
# differential_evolution step 169: f(x)= 93305.8
# differential_evolution step 170: f(x)= 93305.8
# differential_evolution step 171: f(x)= 93305.8
# differential_evolution step 172: f(x)= 93305.8
# differential_evolution step 173: f(x)= 93305.8
# differential_evolution step 174: f(x)= 93305.8
# differential_evolution step 175: f(x)= 93305.8
# differential_evolution step 176: f(x)= 93305.8
# differential_evolution step 177: f(x)= 93305.8
# differential_evolution step 178: f(x)= 93305.8
# differential_evolution step 179: f(x)= 93305.8
# differential_evolution step 180: f(x)= 93305.8
# differential_evolution step 181: f(x)= 93305.8
# differential_evolution step 182: f(x)= 93305.8
# differential_evolution step 183: f(x)= 93305.8
# differential_evolution step 184: f(x)= 93305.8
# differential_evolution step 185: f(x)= 93305.8
# differential_evolution step 186: f(x)= 93305.8
# differential_evolution step 187: f(x)= 93305.8
# differential_evolution step 188: f(x)= 93305.8
# differential_evolution step 189: f(x)= 93305.8
# differential_evolution step 190: f(x)= 93305.8
# differential_evolution step 191: f(x)= 93305.8
# differential_evolution step 192: f(x)= 93305.8
# differential_evolution step 193: f(x)= 93305.8
# differential_evolution step 194: f(x)= 93305.8
# differential_evolution step 195: f(x)= 93305.8
# differential_evolution step 196: f(x)= 93305.8
# differential_evolution step 197: f(x)= 93305.8
# differential_evolution step 198: f(x)= 93305.8
# differential_evolution step 199: f(x)= 93305.8
# differential_evolution step 200: f(x)= 93305.8
# differential_evolution step 201: f(x)= 93305.8
# differential_evolution step 202: f(x)= 93305.8
# differential_evolution step 203: f(x)= 93305.8
# differential_evolution step 204: f(x)= 93305.8
# differential_evolution step 205: f(x)= 93305.8
# differential_evolution step 206: f(x)= 93305.8
# differential_evolution step 207: f(x)= 93305.8
# differential_evolution step 208: f(x)= 93305.8
# differential_evolution step 209: f(x)= 93305.8
# differential_evolution step 210: f(x)= 93305.8
# differential_evolution step 211: f(x)= 93305.8
# differential_evolution step 212: f(x)= 93305.8
# differential_evolution step 213: f(x)= 93305.8
# differential_evolution step 214: f(x)= 93305.8
# differential_evolution step 215: f(x)= 93305.8
# differential_evolution step 216: f(x)= 93305.8
# differential_evolution step 217: f(x)= 93305.8
# differential_evolution step 218: f(x)= 93305.8
# differential_evolution step 219: f(x)= 93305.8
# differential_evolution step 220: f(x)= 93305.8
# differential_evolution step 221: f(x)= 93305.8
# differential_evolution step 222: f(x)= 93305.8
# differential_evolution step 223: f(x)= 93305.8
# differential_evolution step 224: f(x)= 93305.8
# differential_evolution step 225: f(x)= 93305.8
# differential_evolution step 226: f(x)= 93305.8
# differential_evolution step 227: f(x)= 93305.8
# differential_evolution step 228: f(x)= 93305.8
# differential_evolution step 229: f(x)= 93305.8
# differential_evolution step 230: f(x)= 93305.8
# differential_evolution step 231: f(x)= 93305.8
# differential_evolution step 232: f(x)= 93305.8
# differential_evolution step 233: f(x)= 93305.8
# differential_evolution step 234: f(x)= 93305.8
# differential_evolution step 235: f(x)= 93305.8
# differential_evolution step 236: f(x)= 93305.8
# differential_evolution step 237: f(x)= 93305.8
# differential_evolution step 238: f(x)= 93305.8
# differential_evolution step 239: f(x)= 93305.8
# differential_evolution step 240: f(x)= 93305.8
# differential_evolution step 241: f(x)= 93305.8
# differential_evolution step 242: f(x)= 93305.8
# differential_evolution step 243: f(x)= 93305.8
# differential_evolution step 244: f(x)= 93305.8
# differential_evolution step 245: f(x)= 93305.8
# differential_evolution step 246: f(x)= 93305.8
# differential_evolution step 247: f(x)= 93305.8
# differential_evolution step 248: f(x)= 93305.8
# differential_evolution step 249: f(x)= 93305.8
# differential_evolution step 250: f(x)= 93305.8
# differential_evolution step 251: f(x)= 93305.8
# differential_evolution step 252: f(x)= 93305.8
# differential_evolution step 253: f(x)= 93305.8
# differential_evolution step 254: f(x)= 93305.8
# differential_evolution step 255: f(x)= 93305.8
# differential_evolution step 256: f(x)= 93305.8
# differential_evolution step 257: f(x)= 93305.8
# differential_evolution step 258: f(x)= 93305.8
# differential_evolution step 259: f(x)= 93305.8
# differential_evolution step 260: f(x)= 93305.8
# differential_evolution step 261: f(x)= 93305.8
# differential_evolution step 262: f(x)= 93305.8
# differential_evolution step 263: f(x)= 93305.8
# differential_evolution step 264: f(x)= 93305.8
# differential_evolution step 265: f(x)= 93305.8
# differential_evolution step 266: f(x)= 93305.8
# differential_evolution step 267: f(x)= 93305.8
# differential_evolution step 268: f(x)= 93305.8
# differential_evolution step 269: f(x)= 93305.8
# differential_evolution step 270: f(x)= 93305.8
# differential_evolution step 271: f(x)= 93305.8
# differential_evolution step 272: f(x)= 93305.8
# differential_evolution step 273: f(x)= 93305.8
# differential_evolution step 274: f(x)= 84124.6
# differential_evolution step 275: f(x)= 84124.6
# differential_evolution step 276: f(x)= 84124.6
# differential_evolution step 277: f(x)= 84124.6
# differential_evolution step 278: f(x)= 84124.6
